# %% [markdown]
# ### Importing the necessary packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Importing the Dataset

# %%
#Importing the  train dataset
train_data = pd.read_csv("C:/Users/Sowmya Ganesh/Documents/train.csv")
print(train_data.head(5))
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0      81.0        0.0       3          13     16
# 1      80.0        0.0       8          32     40
# 2      80.0        0.0       5          27     32
# 3      75.0        0.0       3          10     13
# 4      75.0        0.0       0           1      1

# %%
#Creating a copy of the Data
data = train_data.copy()

# %% [markdown]
# ### Basic information Check

# %%
data.shape
# Out:
# (12980, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12980 entries, 0 to 12979
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    12980 non-null  object
#  1   season      12980 non-null  int64
#  2   holiday     12980 non-null  int64
#  3   workingday  12980 non-null  int64
#  4   weather     12980 non-null  int64
#  5   temp        12980 non-null  float64
#  6   atemp       12980 non-null  float64
#  7   humidity    12980 non-null  float64
#  8   windspeed   12980 non-null  float64
#  9   casual      12980 non-null  int64
#  10  registered  12980 non-null  int64
#  11  count       12980 non-null  int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# ### No null values found.
# ### There are 12980 rows and 12 columns.

# %%
data.describe().T
# Out:
#               count        mean         std   min      25%      50%       75%  \
# season      12980.0    2.211479    1.053046  1.00   1.0000    2.000    3.0000
# holiday     12980.0    0.027504    0.163553  0.00   0.0000    0.000    0.0000
# workingday  12980.0    0.685978    0.464143  0.00   0.0000    1.000    1.0000
# weather     12980.0    1.426656    0.647955  1.00   1.0000    1.000    2.0000
# temp        12980.0   19.725422    7.828902  0.82  13.1200   19.680   26.2400
# atemp       12980.0   23.112436    8.552046  0.00  15.9100   23.485   30.3050
# humidity    12980.0   62.358552   19.963696  0.00  47.0000   62.000   79.0000
# windspeed   12980.0   13.141760    8.325987  0.00   7.0015   12.998   19.0012
# casual      12980.0   32.441757   46.636228  0.00   3.0000   14.000   42.0000
# registered  12980.0  135.136055  131.921431  0.00  30.0000  103.000  194.0000
# count       12980.0  167.577812  160.758887  1.00  35.0000  124.000  245.0000
#
#                  max
# ...

# %% [markdown]
# ### Exploratory Data Analysis(EDA)

# %%
data.head(2)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0      81.0        0.0       3          13     16
# 1      80.0        0.0       8          32     40

# %%
data.season.value_counts()
# Out:
# season
# 2    4409
# 1    3980
# 3    2457
# 4    2134
# Name: count, dtype: int64

# %%
data.workingday.value_counts()
# Out:
# workingday
# 1    8904
# 0    4076
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x="workingday")
# Out:
# <Axes: xlabel='workingday', ylabel='count'>

# %%
data.weather.value_counts()
# Out:
# weather
# 1    8576
# 2    3273
# 3    1128
# 4       3
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x="weather")
# Out:
# <Axes: xlabel='weather', ylabel='count'>

# %%
data.temp.value_counts()
# Out:
# temp
# 25.42    549
# 13.94    508
# 24.60    507
# 26.24    499
# 14.76    491
# 12.30    470
# 16.40    466
# 28.70    464
# 13.12    463
# 18.86    461
# 22.96    457
# 27.06    455
# 22.14    446
# 21.32    445
# 17.22    430
# 20.50    417
# 18.04    401
# 10.66    397
# 9.84     388
# 29.52    372
# 9.02     361
# 30.34    344
# 8.20     318
# 15.58    269
# 31.16    244
# 23.78    238
# 19.68    236
# 27.88    232
# 11.48    223
# 6.56     222
# 32.80    199
# 7.38     151
# 33.62    139
# 5.74     135
# 31.98    100
# 34.44     85
# 35.26     80
# 4.92      76
# 36.90     58
# 4.10      51
# 36.08     25
# 37.72     21
# 3.28      17
# 0.82      17
# 2.46      16
# 1.64      16
# 38.54     10
# 39.36     10
# 40.18      1
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x="temp")
# Out:
# <Axes: xlabel='temp', ylabel='count'>

# %%
data.humidity.value_counts()
# Out:
# humidity
# 88.0    516
# 94.0    482
# 83.0    434
# 87.0    365
# 55.0    275
#        ...
# 13.0      1
# 12.0      1
# 8.0       1
# 10.0      1
# 97.0      1
# Name: count, Length: 88, dtype: int64

# %%
sns.countplot(data=data,x="humidity")
# Out:
# <Axes: xlabel='humidity', ylabel='count'>

# %%
data.casual.value_counts()
# Out:
# casual
# 0      1286
# 1       852
# 2       613
# 3       557
# 4       453
#        ...
# 163       1
# 298       1
# 282       1
# 278       1
# 239       1
# Name: count, Length: 302, dtype: int64

# %%
data.registered.value_counts()
# Out:
# registered
# 4      264
# 3      252
# 2      220
# 5      219
# 6      196
#       ...
# 610      1
# 419      1
# 646      1
# 645      1
# 597      1
# Name: count, Length: 674, dtype: int64

# %%
sns.countplot(data=data,x="casual")
# Out:
# <Axes: xlabel='casual', ylabel='count'>

# %%
sns.countplot(data=data,x="registered")
# Out:
# <Axes: xlabel='registered', ylabel='count'>

# %%
sns.heatmap(data[["count","weather","temp","humidity","casual","registered","season","atemp","windspeed"]].corr(),annot=True,cmap='RdBu',cbar=True)
# Out:
# <Axes: >

# %%
### From the above EDA we have the following insights
### In season 2 the count is greater.
### Weather 1 has the greater count.
### The count is greater when humidity is 88.0 
### the count is greater when the temperature is 25.42

### From the heatmap we can infer that
### Count is more correlated with registered,casual,temp,atemp and  humidity.
### Since we have both nominal and continuous data and many dependent
### variables,we can go for Multiple linear regression model.
